# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Роман! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# # Сборный проект-4
#
# Вам поручено разработать демонстрационную версию поиска изображений по запросу.
#
# Для демонстрационной версии нужно обучить модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — покажет, насколько текст и картинка подходят друг другу.
#
# ### Описание данных
#
# Данные доступны по [ссылке](https://code.s3.yandex.net/datasets/dsplus_integrated_project_4.zip).
#
# В файле `train_dataset.csv` находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `train_images` содержатся изображения для тренировки модели.
#
# В файле `CrowdAnnotations.tsv` — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
# 3. Доля людей, подтвердивших, что описание соответствует изображению.
# 4. Количество человек, подтвердивших, что описание соответствует изображению.
# 5. Количество человек, подтвердивших, что описание не соответствует изображению.
#
# В файле `ExpertAnnotations.tsv` содержатся данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
#
# 3, 4, 5 — оценки трёх экспертов.
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
#
# В файле `test_queries.csv` находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `test_images` содержатся изображения для тестирования модели.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Да, это хорошая практика - дать описание контекста и проблемы, которую мы решаем. </div>

# %% [markdown]
# ## План
# 1. Проведение исследовательского анализа данных, включая загрузку и первичный осмотр тренировочных и тестовых наборов с изображениями и текстовыми запросами, а также данных экспертных и краудсорсинговых оценок.
# 2. Осуществление проверки качества данных и их предварительной обработки, выявление и фильтрация нежелательного контента на основе списка блокируемых слов.
# 3. Реализация процесса векторизации изображений с использованием предобученной модели.
# 4. Организация векторизации текстовых запросов посредством SBERT-модели.
# 5. Процедура объединения векторных представлений изображений и текстов в единую матрицу признаков для последующего обучения моделей.
# 6. Проведение сравнительного анализа различных алгоритмов машинного обучения, включая настройку гиперпараметров и оценку эффективности на кросс-валидации.
# 7. Финальное тестирование отобранной модели на тестовом наборе данных с визуальной проверкой качества поиска изображений.

# %%
# !pip install -q tf-keras
# !pip install -q sentence-transformers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error
import nltk
import re
import os
from PIL import Image
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GroupShuffleSplit, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from tensorflow.keras.applications.resnet50 import preprocess_input
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords as nltk_stopwords


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet import ResNet50

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Input, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model


from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, GroupShuffleSplit

import warnings
warnings.filterwarnings("ignore", category=FutureWarning, 
                        message=".*encoder_attention_mask.*is deprecated.*")
# Out:
# WARNING:tensorflow:From C:\Users\Risik\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %%
nltk.download('stopwords', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)
# Out:
# True

# %%
DATAFRAME_PATH = "datasets/"
TRAIN_IMAGE_PATH = "datasets/train_images/"
TEST_IMAGE_PATH = "datasets/test_images/"
BLOCK_WORDS_PATH = "block/"
EXPERT_WEIGHT = .7
TRAIN_SIZE = .8
SEED = 125

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Большое тебе человеческое спасибо за вынос пути к данным в отдельную константу. Это сэкономило мне немало времени при проверке.
#
#
# </div>

# %%
tf.random.set_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## 1. Исследовательский анализ данных
#
# Наш датасет содержит экспертные и краудсорсинговые оценки соответствия текста и изображения.
#
# В файле с экспертными мнениями для каждой пары изображение-текст имеются оценки от трёх специалистов. Для решения задачи вы должны эти оценки агрегировать — превратить в одну. Существует несколько способов агрегации оценок, самый простой — голосование большинства: за какую оценку проголосовала большая часть экспертов (в нашем случае 2 или 3), та оценка и ставится как итоговая. Поскольку число экспертов меньше числа классов, может случиться, что каждый эксперт поставит разные оценки, например: 1, 4, 2. В таком случае данную пару изображение-текст можно исключить из датасета.
#
# Вы можете воспользоваться другим методом агрегации оценок или придумать свой.
#
# В файле с краудсорсинговыми оценками информация расположена в таком порядке:
#
# 1. Доля исполнителей, подтвердивших, что текст **соответствует** картинке.
# 2. Количество исполнителей, подтвердивших, что текст **соответствует** картинке.
# 3. Количество исполнителей, подтвердивших, что текст **не соответствует** картинке.
#
# После анализа экспертных и краудсорсинговых оценок выберите либо одну из них, либо объедините их в одну по какому-то критерию: например, оценка эксперта принимается с коэффициентом 0.6, а крауда — с коэффициентом 0.4.
#
# Ваша модель должна возвращать на выходе вероятность соответствия изображения тексту, поэтому целевая переменная должна иметь значения от 0 до 1.

# %% [markdown]
# ### 1.1. Загрузка данных.

# %%
# функция загрузки данных в датафрейм
def df_load(file_name, *arg, path=DATAFRAME_PATH, columns_name=None, index_col=None, header='infer'):
    if not os.path.exists(path + file_name):
        raise ValueError(f'Файл {file_name} не найден.')
    try:
        df = pd.read_csv(path + file_name, sep=arg[0], decimal=arg[1], index_col=index_col, header=header)
        print(f'Данные {file_name} успешно загружены')
    except Exception as err:
        raise ValueError(f'Ошибка загрузки данных из файла {file_name}: {err}')
    if columns_name is not None:
        df.columns = columns_name
    print(f'Размерность датафрейма: {df.shape}\n'
          'Общая информация о датафрейме:')
    print(df.info())
    return(df)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Пожалуйста перепроверь логику своей функции. Дело в том, что она "съедает" первую строку датафрейма, если в нем не определены колонки.
#
# В датафрейме с экспертными оценками должно быть 5822 записии, а у тебя после чтения получается 5821.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# В фукнкцию добавлен параметр <b>header</b>. Для датафреймов без заголовков устанавливается в <b>None</b>.
# </div>

# %%
# загрузка экспертных оценок
df_expert = df_load(
    'ExpertAnnotations.tsv',
    '\t',
    '.',
    columns_name=['image', 'query_id', '1', '2', '3'],
    header=None
)
# Out:
# Данные ExpertAnnotations.tsv успешно загружены
# Размерность датафрейма: (5822, 5)
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     5822 non-null   object
#  1   query_id  5822 non-null   object
#  2   1         5822 non-null   int64
#  3   2         5822 non-null   int64
#  4   3         5822 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 227.6+ KB
# None

# %%
# загрузка оценок краудсорсинга
df_crowd = df_load(
    'CrowdAnnotations.tsv',
    '\t',
    '.',
    columns_name=['image', 'query_id', 'fraction_yes', 'count_yes', 'count_no']
)
# Out:
# Данные CrowdAnnotations.tsv успешно загружены
# Размерность датафрейма: (47829, 5)
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47829 entries, 0 to 47828
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   image         47829 non-null  object
#  1   query_id      47829 non-null  object
#  2   fraction_yes  47829 non-null  float64
#  3   count_yes     47829 non-null  int64
#  4   count_no      47829 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB
# None

# %%
# загрузка тренировочных данных
df_train = df_load('train_dataset.csv', ',', '.')
# Out:
# Данные train_dataset.csv успешно загружены
# Размерность датафрейма: (5822, 3)
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# None

# %%
# загрузка тестовых запросов
df_test = df_load('test_queries.csv', '|', '.', index_col=[0])
# Out:
# Данные test_queries.csv успешно загружены
# Размерность датафрейма: (500, 3)
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   query_id    500 non-null    object
#  1   query_text  500 non-null    object
#  2   image       500 non-null    object
# dtypes: object(3)
# memory usage: 15.6+ KB
# None

# %%
# загрузка тестовых изображений
df_test_img = df_load('test_images.csv', ',', '.')
# Out:
# Данные test_images.csv успешно загружены
# Размерность датафрейма: (100, 1)
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   100 non-null    object
# dtypes: object(1)
# memory usage: 932.0+ bytes
# None

# %%
# загрузка блок слов
block_words = df_load('child_block.csv', ',', '.', path=BLOCK_WORDS_PATH)
# Out:
# Данные child_block.csv успешно загружены
# Размерность датафрейма: (74, 1)
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   blockwords  74 non-null     object
# dtypes: object(1)
# memory usage: 724.0+ bytes
# None

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# ОК, данные загружены.</div>

# %% [markdown]
# ### 1.2. Изучение данных.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Человеческий мозг может одновременно уделять внимание ограниченному числу объектов (обычно 7 плюс минус 2, в зависимости от сложности).
#
# Поэтому я бы советовал с каждым датафреймом познакомиься в отдельном разделе, выведя head/info, возможно изучив пропуски/описательные статистики.  Т.е. не все одновременно, а последовательно фокусируясь на каждом.
# </div>

# %%
# вывод данных из датафрейма
df_expert.sample(5)
# Out:
#                           image                     query_id  1  2  3
# 471   1561658940_a947f2446a.jpg  1714316707_8bbaa2a2ba.jpg#2  1  1  2
# 413   1490670858_e122df2560.jpg  1258913059_07c613f7ff.jpg#2  1  1  1
# 3710  3295391572_cbfde03a10.jpg  3259666643_ae49524c81.jpg#2  1  1  1
# 2200  2796801478_8ebd7e550b.jpg   500446858_125702b296.jpg#2  1  1  1
# 4193  3462454965_a481809cea.jpg  2718024196_3ff660416a.jpg#2  1  1  1

# %%
# вывод данных из датафрейма
df_crowd.sample(5)
# Out:
#                            image                     query_id  fraction_yes  \
# 151    1084040636_97d9633581.jpg  2926233397_71e617f3a3.jpg#2           0.0
# 9300   2308978137_bfe776d541.jpg  3605061440_1d08c80a57.jpg#2           0.0
# 8379   2248487950_c62d0c81a9.jpg  1082379191_ec1e53f996.jpg#2           0.0
# 9763   2351479551_e8820a1ff3.jpg  2167644298_100ca79f54.jpg#2           0.0
# 26987  3197917064_e679a44b8e.jpg  3259002340_707ce96858.jpg#2           0.0
#
#        count_yes  count_no
# 151            0         3
# 9300           0         3
# 8379           0         3
# 9763           0         3
# 26987          0         3

# %%
# вывод данных из датафрейма
df_train.sample(5)
# Out:
#                           image                     query_id  \
# 1654  2704934519_457dc38986.jpg  2196846255_2c1635359a.jpg#2
# 2822  3473264983_67917a931f.jpg  3494394662_3edfd4a34c.jpg#2
# 5521  3545652636_0746537307.jpg  3217620013_8b17873273.jpg#2
# 2454  2999730677_0cfa1c146e.jpg  3263395801_5e4cee2b9e.jpg#2
# 3568   488590040_35a3e96c89.jpg   400851260_5911898657.jpg#2
#
#                                              query_text
# 1654           A wrinkled dog wading in shallow water .
# 2822  A man with a red collar and gray beard looks a...
# 5521  A man in a red uniform is playing backset ball...
# 2454  A motocross bike is being ridden along a woodl...
# 3568  A mist overshadows a man in winter gear and th...

# %%
# вывод данных из датафрейма
df_test.sample(5)
# Out:
#                         query_id  \
# 26   1468389504_c724bdcad0.jpg#1
# 440   440190907_bf8b7ba8ef.jpg#0
# 105  2431120202_b24fe2333a.jpg#0
# 9    1232148178_4f45cc3284.jpg#4
# 360  3482859574_3908de3427.jpg#0
#
#                                             query_text  \
# 26                         Two girls on a jungle gym .
# 440   A group of people walk through a shopping mall .
# 105                        A girl cross-country skis .
# 9    There is a little blond hair girl with a green...
# 360  A group of girls wearing costumes stand in a p...
#
#                          image
# 26   1468389504_c724bdcad0.jpg
# 440   440190907_bf8b7ba8ef.jpg
# 105  2431120202_b24fe2333a.jpg
# 9    1232148178_4f45cc3284.jpg
# 360  3482859574_3908de3427.jpg

# %%
# вывод данных из датафрейма
df_test_img.sample(5)
# Out:
#                         image
# 81  3514297698_0512623955.jpg
# 73  2737233999_34d60dc5c3.jpg
# 89  2687672606_275169c35d.jpg
# 13  3438981089_2ef1a6353c.jpg
# 97  3091962081_194f2f3bd4.jpg

# %%
# вывод данных из датафрейма
block_words.sample(5)
# Out:
#     blockwords
# 24    schooler
# 3       infant
# 7   adolescent
# 67       wards
# 43      youths

# %%
# выводим 8 тренировочных изображений
fig = plt.figure(figsize=(8,8))
fig.suptitle("Тренировочные изображения", fontsize=16)
for i, image_file in enumerate(df_train['image'].sample(8)):
    fig.add_subplot(2, 4, i+1)
    image = Image.open(os.path.join(TRAIN_IMAGE_PATH, image_file))
    plt.imshow(image)
    plt.axis('off')
    plt.title(os.path.basename(image_file), fontsize=8)
plt.tight_layout()
plt.show()

# %%
print(f'Уникальных фото в тренировчных данных - {len(df_train['image'].unique())}')
# Out:
# Уникальных фото в тренировчных данных - 1000

# %%
print(f'Уникальных комбинаций фото + описание с экспертной оценкой - {len(df_expert.groupby(['image', 'query_id']))}')
# Out:
# Уникальных комбинаций фото + описание с экспертной оценкой - 5822

# %%
print(f'Уникальных  комбинаций фото + описание с краудсорсинговой оценкой - {len(df_crowd.groupby(['image', 'query_id']))}')
# Out:
# Уникальных  комбинаций фото + описание с краудсорсинговой оценкой - 47829

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Проведено первичное знакоство с загружеными данными</div>

# %% [markdown]
# ### 1.3. Исследование оценок.

# %% [markdown]
# Посмотрим на распределение экспертных оценок. Количественно сколько разных оценок было проставлено каждым экспертом.

# %%
# визуализация оценок экспертов
plt.figure(figsize=(10, 6))
sns.histplot(data=df_expert[['1','2','3']], bins=5, alpha=0.5, discrete=True)
plt.title('Распределение оценок экспертов', fontsize=16)
plt.xlabel('Оценка', fontsize=12)
plt.ylabel('Количество', fontsize=12)
plt.legend(title='Эксперт', labels=['Эксперт 1', 'Эксперт 2', 'Эксперт 3'])
plt.xticks([1, 2, 3, 4])
plt.show()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# Как видим эксперты определили, что в большинстве случаев текст не соотвествует картинке.

# %% [markdown]
# Рассмотрим распределение оценок краудсорсинга. Для оценки соответствия будем использовать преобладающее количество голосов.

# %%
# визуализация оценок краусорсинга
plt.figure(figsize=(10, 4))
ax = sns.countplot(
    data=df_crowd.apply(
        lambda x: "Соответствует" if x.count_yes > x.count_no else "Не соответствует",
        axis=1
    ),
    order=["Соответствует", "Не соответствует"]
)

ax.set_xlabel('Количество', fontsize=12)
ax.set_ylabel('Оценка', fontsize=12)
ax.set_title('Распределение оценок краудосорсинга', fontsize=14, pad=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# Оценки краудсорсинга также говорят, что большинтво описаний не соответсвует изображению.

# %% [markdown]
# Выведем обобщенную оценку соответсвия:
# * Для экспертной оценки создадим среднуюю нормализованную оценку
# * Для краудсорсинга так же сделаем нормализованную оценку, как отношение количества положительных оценок ко всем оценкам

# %%
# оценка экспертов - среднее нормализованное значение
#df_expert['expert_norm'] = df_expert[['1', '2', '3']].mean(axis=1) / 4
df_expert['expert_norm'] = (df_expert[['1', '2', '3']].mean(axis=1) - 1) / 3

# оценка краудсорсинга - доля положительных оценок
# на случай если оценок нет совсем ставим значение 0.5 (50/50 - соответсвия)
# df_crowd['crowd_norm'] = np.where(
#     (df_crowd['count_yes'] + df_crowd['count_no']) > 0,
#     df_crowd['count_yes'] / (df_crowd['count_yes'] + df_crowd['count_no']),
#     .5
# )

df_crowd['crowd_norm'] = df_crowd['fraction_yes']

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Экспертные оценки находятся в диапазоне 1-4 (в том числе и средняя оценка). Деля их на 4 мы получаем диапазон 0,25-1. Поэтому вместо деления на 4 нужно использовать другое линейное преобразование: (x-1) /3
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Расчет оценки эксперта изменен на <b>(x - 1) / 3</b>.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
#
# У тебя уже есть рассчитанная "доля" краудсорсеров, подтвердивших соответствие - это колонка `fraction_yes`. Если ты выведешь датафрейм, то увидишь что в них содержится одинаковые значения.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Да это я совсем упустил из вида, можно было не рассчитывать.
# </div>

# %% [markdown]
# Теперь нужно объеденить датафреймы с оценками. Т.к. в датафреймах разное количество оцененных описаний, то объединять будем методом OUTER.

# %%
df_merged = pd.merge(
    df_expert[['image', 'query_id', 'expert_norm']],
    df_crowd[['image', 'query_id', 'crowd_norm']],
    how='outer',
    on=['image', 'query_id']
)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# По объединению экспертных и крауд оценок все ОК, но подсвечу возможные альтернативы
#
# --------------
#
#
# В этом проекте есть несколько возможных стратегий работы с обучающими и краудсорс оценками,  вот эти стратегии с плюсами и минусами:
#
#
#    - использовать соединение через outer, в этом случае, при корректной обработке пропусков мы можем получить более 50К размеченых пар. К плюсам данного подхода можно отнести большое количество данных. Минус - в основном это будут данные, размеченные краудсорсерами, а там качество раметки ниже.
#    - использовать только экспертные оценки. плюс - высокое качество данных (разметка имеет шкалу). Минус - данных меньше.  Поясню по поводу качества разметки на примере: если на изображении одна собака, а в описании "две собаки бегут по берегу", то эксперты поставять соответствие 0,6-0,7 (переводя в шкалу 0-1), а краудсорсеры поставят 0.  Но на экспертных оценках модель хотя-бы научится находить собак, а на краудсор оценках ничему не начится.
#
#    - использование соединения через left.  Данный подход очевидно проигрывает второму варианту: данных столько же, нужно дополнительно возиться с объединением, но качество разметки снижается.. Но это соответсвует предложениям авторов проекта, поэтому такой подход имеет право на жизнь
#
#    - объединение через inner. Тут все плохо - и данных ОЧЕНЬ мало (в два раза меньше, чем использовать только экспертные оценки) и качество у них "подпорчено". И навыков по обработке пропусков не получаем.....
#
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Но все-таки хочу подчеркнуть некоторую неоптимальность. Ты выполняешь достаточно трудоемкий вариант с соединением outer. однако впоследствии все равно "пересекаешьё" с датафреймом `df_train`, поэтому итоговый датасет, который мы получим будет соотвтствовать варианту "соединение слева"
#
# -------------
#
# Это станет очевидно, если учесть, что датафреймы `df_train` и `df_expert` содержат одни и те же пары объектов (изображение + описание).
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Не подумал, что эксперты оценивали пары из трейна. Действительно сделать JOIN LEFT всех трех датафреймов было бы проще.
# </div>

# %% [markdown]
# Оценим количество пропусков полученных в результате объединения.

# %%
# посчитаем количество пропусков в оценках
nan_expert = df_merged['expert_norm'].isna().sum()
nan_crowd = df_merged['crowd_norm'].isna().sum()
print(f"Отсутствует экспертных оценок: {nan_expert}, crowd-оценок: {nan_crowd}")
# Out:
# Отсутствует экспертных оценок: 45500, crowd-оценок: 3493

# %% [markdown]
# Создадим обобщенную оценку соответсвия, как сумму оценок экспертов и краудсорсинга, с учетом веса оценки эксперта. В случае если какая-либо из оценок отвутсвует, в качестве обобщенной оценки берем оставшуюся без учета веса.

# %%
# создаем признак финальной оценки
df_merged['final_score'] = np.where(
    df_merged['expert_norm'].isna(),
    df_merged['crowd_norm'],
    np.where(
        df_merged['crowd_norm'].isna(),
        df_merged['expert_norm'],
        df_merged['expert_norm'] * EXPERT_WEIGHT + df_merged['crowd_norm'] * (1 - EXPERT_WEIGHT)
    )
)

# %%
df_merged = df_merged[['image', 'query_id', 'final_score']].copy()

# %%
# вывод информа о полученном датафрейме
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51322 entries, 0 to 51321
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image        51322 non-null  object
#  1   query_id     51322 non-null  object
#  2   final_score  51322 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# ОК, получена итоговая агрегированная оценка.</div>

# %% [markdown]
# ### Вывод по разделу:
# * Загрузили данные с тренировочными, тестовыми запросами. А также данные с оценками от экспертов и краудсорсинга.
# * Осмотрели загруженные данные, а так же выборочно помотрели изображения предоставленные для обучения.
# * Сравнили распределение оценок от экспертов и краудсорсинга. Большинство оценок указывают на то, что описание не соотвествует изображению.
# * Создали номализованные оценки соотвествия экспертов и краудсорсинга.
# * Объеденили данные от разных оценщиков в один датафрейм.
# * Вычислили обобщенную оценку соответствия на основе имеющихся оценок.

# %% [markdown]
# ## 2. Проверка данных
#
# В некоторых странах, где работает ваша компания, действуют ограничения по обработке изображений: поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно тексты, изображения, видео и аудио, содержащие описание, изображение или запись голоса детей. Ребёнком считается любой человек, не достигший 16 лет.
#
# В вашем сервисе строго следуют законам стран, в которых работают. Поэтому при попытке посмотреть изображения, запрещённые законодательством, вместо картинок показывается дисклеймер:
#
# > This image is unavailable in your country in compliance with local laws
# >
#
# Однако у вас в PoC нет возможности воспользоваться данным функционалом. Поэтому все изображения, которые нарушают данный закон, нужно удалить из обучающей выборки.

# %% [markdown]
# Создадим кастомный класс для очистки, токенизации и лемматизации текста (почти целиком скопировал из предыдущей работы по обработке тестов).

# %% [markdown]
# #### Класс `TextPreprocessor`
#
# Класс для обработки текста
#
# `__init__()`
#    - Инициализация с параметрами:
#      - `lang` - язык текста (по умолчанию 'english')
#      - `block` - список слов для блокировки
#    - Создает:
#      - Лемматизатор WordNetLemmatizer
#      - Список стоп-слов
#      - Регулярные выражения для очистки
#
# `_get_pos()` *(внутренний)*
#    - Определяет часть речи для лемматизации:
#      - J → прилагательное ('a')
#      - V → глагол ('v')
#      - N → существительное ('n')
#      - R → наречие ('r')
#      - По умолчанию → 'n'
#
# `_clean_text()` *(внутренний)*
#    - Выполняет базовую очистку текста:
#      1. Удаление спецсимволов (для английского)
#      2. Приведение к нижнему регистру
#      3. Удаление лишних пробелов
#
# `preprocess_text()` *(основной)*
#    - Полный pipeline обработки текста:
#      1. Очистка текста (`_clean_text`)
#      2. Токенизация
#      3. Удаление стоп-слов
#      4. Проверка на блокируемые слова
#      5. Лемматизация (`_get_pos`)
#      6. Склейка токенов в строку
#
# `transform()` *(основной)*
#    - Применяет `preprocess_text` ко всем текстам
#    - Возвращает pd.Series с обработанными данными
#    - Совместимость с scikit-learn Pipeline
#
# `fit()` *(основной)*
#    - Обязательный метод для scikit-learn
#    - Заглушка

# %%
# класс предобработки текста
class TextPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self, lang='english', block=None):
        self.lemm = WordNetLemmatizer()
        self.lang = lang
        self.stopwords = nltk_stopwords.words(self.lang)
        self.block = block

    def get_pos(self, tag):
        if tag.startswith('J'):
            return 'a'
        elif tag.startswith('V'):
            return 'v'
        elif tag.startswith('N'):
            return 'n'
        elif tag.startswith('R'):
            return 'r'
        return 'n'
        
    def preprocess_text(self, text):
        if self.lang == 'english':
            text = re.sub(r"[^a-zA-Z\s]", "", text).lower()
        tokens = word_tokenize(text, language=self.lang)
        tokens = [word for word in tokens if word not in self.stopwords]
        if self.block and any(word in self.block for word in tokens):
            tokens = ["BLOCK"]
        pos_tags = pos_tag(tokens)
        final_tokens = []
        for token, tag in pos_tags:
            lemma = self.lemm.lemmatize(
                token,
                pos=self.get_pos(tag)
            )
            final_tokens.append(lemma)          
        return ' '.join(final_tokens)
        
    def fit(self, X, y=None):
        return self
        
    def transform(self, X):
        return X.apply(self.preprocess_text)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Идея с лемматизацией хороша. Но она очень "дорогая" - хорошая лемматизация занимает время. Кроме того ведь её нужно написать, проверить на ошибки, возможно "утащить в прод"..
#
# А между тем лемматизация  нужна нам в двух случаях:
#
#  - При чистке датасета от детских изображений.
#  - При векторизации.
#
# При поиске детских изображений я  считаю возможным упростить себе жизнь - взять возможные словоформы "запрещенных" слов. Как правиль их всего две - единственное и множественное число.
#
# А для вкторизациии делать лемматизацию в нашем случае не нужно. Модель BERT обучалась на обычных, сырых,не лемматизированных текстах.
#
#
# </div>

# %%
# преобразуем блок слова в плоский список и запускаем процесс предобработки текста
preprocessor = TextPreprocessor(block=block_words['blockwords'].values.flatten().tolist())
df_train['query_text_prep'] = preprocessor.transform(df_train['query_text'])

# %%
# объеденяем датафреймы с данными и оценками
df_train = pd.merge(
    df_train,
    df_merged,
    how='inner',
    on=['image', 'query_id']
)

# %%
# оценивает размерность полученного латафрейма
df_train.shape
# Out:
# (5822, 5)

# %%
# создадим список query_id описание для которых содержит запрещенные слова
blocked_images = df_train.loc[
    df_train['query_text_prep'] == 'BLOCK',
    'query_id'
].tolist()

# %%
# удалим суффиксы в query_id чтобы получить список изображений
blocked_images = [x[:-2] for x in blocked_images]

# %% [markdown]
# Визуализируем изображения которые мы хотим заблокировать для обучения.

# %%
# выделяем блокированные изображения в отдельный датафрейм
#blocked_images = df_train[df_train['query_text_prep'] == "BLOCK"]

# выводим 8 случайных изображений из этого датафрейма
blocked_choise = np.random.choice(blocked_images, size=8, replace=False)
fig = plt.figure(figsize=(8, 8))
fig.suptitle("Заблокированные изображения", fontsize=16)
for i, image in enumerate(blocked_choise):
    fig.add_subplot(2, 4, i+1)
    image = Image.open(os.path.join(TRAIN_IMAGE_PATH, image))
    plt.imshow(image)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# удалим из трейна изображения комментарии для которых содержат запрещенные слова
df_train = df_train[~df_train['image'].isin(blocked_images)]

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Среди изображений, которые ты выводишь для проверки часть содерит изображения, не относящиеся к детям.  И дело здесь не в "плохо подобранных ключевых словах"
#
#
# Дело в том, что ты идешь изображения с детьми" по запросам, но в датафрейме df_train изображения и описания не соответстуют друг другу (там те же пары, что и в датафрейме с экспеертными оценками).
#
#
# Сейчас ты удаляешь из датафрейма описания с детьми, но не изображения с детьми.   Есть два способа, как удалить именно изображения с детьми
#
# Первый - если использовать оценки:
#
#  - Определить список плохих изображений, как изображения удовлетворяющие условиям:
#     - Комментарий содержит плохие слова
#     - <b>Оценка соответствия комментария и изображения выше порога.</b>
#  - Удалить из нашего датасета все пары "изображение/описание" с плохими изображениями.
#
#
# И второй, очень красивый способ. Он основан на том, что `query_id` содержит в с себе имя изображения, для которого он был написан (такая пасхалочка от авторов датасета).
#
#  - Определить список плохих комментариев
#  - У `query_id`  плохих комментариев отрезать два последних символа и получим список плохих изображений.
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# <ol>
#     <li>Объеденил датафреймы сразу</li>
#     <li>Создал список <b>query_id</b> описание для которых содержит блок-слова</li>
#     <li>Удалил суффиксы и получил список изображений для блокировки</li>
#     <li>Отфильтровал данные в трейне по этому списку</li>
# </ol>
# </div>

# %% [markdown]
# ~~В заблокированые попали несколько фото детей. Так же присутсвуют собаки, видимо фильтруются по слову **boy**. Так же несколько фото не относящихся к детям. Но в таком вопросе лучше перебдеть, хотя ключевые слова возможно нуждаются в доработке.~~

# %% [markdown]
# ~~Теперь объеденим датафреймы с тренировочными данными и оценками, изображения которые попали у нас в блок мы не берем.~~

# %%
# оценивает размерность полученного датафрейма
df_train.shape
# Out:
# (4080, 5)

# %% [markdown]
# ### Вывод по разделу
# * Создали кастомный класс для очистки, токенизации и лемматизации текста
# * Нашли описания которые попадают под наш список блок слов
# * Объеденили тренировочные данные с данными оценки
# * Визуализировали изображения которые нам нужно заблокировать, в основном есть совпадения
# * Удалили заблокированные изображения~~и объеденили с данними по оценке соответствия~~
# * Всего удалено `1742` записи.

# %% [markdown]
# ## 3. Векторизация изображений
#
# Перейдём к векторизации изображений.
#
# Самый примитивный способ — прочесть изображение и превратить полученную матрицу в вектор. Такой способ нам не подходит: длина векторов может быть сильно разной, так как размеры изображений разные. Поэтому стоит обратиться к свёрточным сетям: они позволяют "выделить" главные компоненты изображений. Как это сделать? Нужно выбрать какую-либо архитектуру, например ResNet-18, посмотреть на слои и исключить полносвязные слои, которые отвечают за конечное предсказание. При этом можно загрузить модель данной архитектуры, предварительно натренированную на датасете ImageNet.

# %% [markdown]
# Создадим класс для получения эмбеддингов изображения. Структура будет инкапсулировать методы создания генератора изображения и использования предобученной модели для векторизации изображения.

# %% [markdown]
# #### Класс `ImageVectorized`
#
# Класс для преобразования изображения в эмбеддинги
#
# `__init__()`
#    - Инициализация с параметрами:
#      - `input_shape` - размер изображений (по умолчанию 256x256x3)
#      - `backbone_weights` - веса модели ('imagenet')
#    - Создает и настраивает модель ResNet50
#
# `_build_model()` *(внутренний)*
#    - Строит архитектуру:
#      1. ResNet50 без верхних слоев
#      2. Добавляет GlobalAveragePooling
#    - Замораживает веса модели
#
# `_create_generator()` *(внутренний)*
#    - Создает генератор данных из DataFrame:
#      - Автоматическая загрузка изображений
#      - Нормализация (1./255)
#      - Ресайз под нужный размер
#    - Параметры: DataFrame, путь к изображениям, размер батча
#
# `vectorized()` *(основной)*
#    - Полный pipeline обработки:
#      1. Создает генератор
#      2. Применяет модель для векторизации
#      3. Возвращает numpy-массив эмбеддингов

# %%
# класс класс для преобразования изображения
class ImageVectorized:
    def __init__(self, input_shape=(256, 256, 3), backbone_weights='imagenet'):
        self.input_shape = input_shape
        self.backbone_weights = backbone_weights
        self.model = self._build_model()
        
    def _build_model(self):
        backbone = ResNet50(
            input_shape=self.input_shape,
            weights=self.backbone_weights,
            include_top=False
        )     
        backbone.trainable = False
        model = Sequential([
            backbone,
            GlobalAveragePooling2D()
        ])
        return model
        
    def _create_generator(self, df, image_dir, batch_size=16, seed=125):
        #datagen = ImageDataGenerator(rescale=1./255)
        datagen = ImageDataGenerator(
            preprocessing_function=preprocess_input
        )
        
        generator = datagen.flow_from_dataframe(
            dataframe=df,
            directory=image_dir,
            x_col='image',
            y_col=None,
            target_size=self.input_shape[:2],
            batch_size=batch_size,
            class_mode=None,
            shuffle=False
            #seed=seed
        )       
        return generator
        
    def vectorized(self, df, image_dir, batch_size=16, seed=125):
        generator = self._create_generator(df, image_dir, batch_size)
        img_vectorized = self.model.predict(generator)
        return img_vectorized

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Вот здесь проблема, и она заключается в том, что  у flow_from_dataframe есть дефолтный аргумент shuffle=True, а значит выдаваемые им изображения перемешиваются, и идут совсем не в том порядке,как в датфрейме.  Как следствие мы получаем эмбеддинги не соответствующие изображениям в датафрейме.</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# В flow_from_dataframe добавлен <b>shuffle=False</b>. Убран <b>seed=seed</b>.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Модель ResNEt обучалась на изображениях размером 224х224. Подавая изображения других размеров эмбеддинги ты конечно получишь, но их качество вызывает вопросы.
#
# ----------------------------
#
# Более того, чтобы эмбеддинги  были качественными, стоит использовать специальную предобработку, повторяющую условия, при которых модель обучалась.
#
# В разделе "компьютерное зрение с pytorch" приведен образец кода, как проводить эту предобработку при использовани моделей pytorch.
#
# В случае Keras нужно использовать специальную фукнцию preprocess_input
#
#     from keras.applications.resnet50 import preprocess_input
#     ...
#     train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
#
#
# --------------
#
# Важно: препроцессинг в данном случае отменяет необходимость делай рескейл. Т.е. `preprocessing_function` мы указываем вместо `rescale`.
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# <b>rescale</b> заменен на <b>preprocessing_function</b>.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# А еще стоит обратить внимание, что изображения у нас не квадратные, а значит они будут сжаты до квадратов с изменением пропорций.
#
# В прекоде, который был дан в теории для pytorch модели эта проблема была решена тем, что мы вырезали квадрат из середины и работали уже с ним.
#
# Думаю что что-то подобное стоит попробовать и при использовании keras.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Код я нашел:
#
#   <pre><code class="language-python">from torchvision import transforms
# norm = transforms.Normalize(
#     mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# preprocess = transforms.Compose([
#     transforms.Resize(256),
#     transforms.CenterCrop(224),
#     transforms.ToTensor(),
#     norm,
# ])</code></pre>
# Но собственно, понимания что делается
# </div>

# %%
# создаем экземпляр класса 
model_iv = ImageVectorized()

# %%
# запускаем процесс создания эмбеддингов
image_vectorize = model_iv.vectorized(df_train, TRAIN_IMAGE_PATH) #, seed=SEED)
# Out:
# Found 4080 validated image filenames.
# C:\Users\Risik\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 78s 301ms/step

# %%
# проверяем размерность полученного массива
image_vectorize.shape
# Out:
# (4080, 2048)

# %% [markdown]
# ### Вывод по разделу:
# * Создана архитектура на базе ResNet50 с GlobalAveragePooling
# * Загружены изображений из `TRAIN_IMAGE_PATH`, проведен ресайз до 256x256 пикселей и значения нормализованы.
# * Получена матрица эмбеддингов размером ~~`(4252, 2048)`~~ (4080, 2048).

# %% [markdown]
# ## 4. Векторизация текстов
#
# Следующий этап — векторизация текстов. Вы можете поэкспериментировать с несколькими способами векторизации текстов:
#
# - tf-idf
# - word2vec
# - \*трансформеры (например Bert)
#
# \* — если вы изучали трансформеры в спринте Машинное обучение для текстов.

# %% [markdown]
# Создадим класс для получения эмбеддингов текста, на основе предобученной модели `SBERT`.

# %% [markdown]
# #### Класс `TextEmbedder`
#
# Класс для преобразования текста в эмбеддинги
#
# `__init__()`
#    - Инициализация с параметрами:
#      - `model_name` - название модели SBERT (по умолчанию 'all-MiniLM-L6-v2')
#      - `lang` - язык текста (по умолчанию 'english')
#      - `batch_size` - размер батча для обработки (по умолчанию 32)
#    - Настраивает:
#      - Модель для векторизации текстов
#      - Параметры обработки
#
# `_load_model()` *(внутренний)*
#    - Загружает предобученную модель SBERT:
#      1. Инициализирует SentenceTransformer
#      2. Настраивает параметры кодирования
#
# `transform()` *(основной)*
#    - Полный pipeline обработки текста:
#      1. Загрузка модели (при первом вызове)
#      2. Векторизация текстов:
#        - Пакетная обработка (размер батча)
#        - Автоматическая нормализация
#        - Преобразование в numpy-массив
#      3. Возвращает матрицу эмбеддингов
#
# `fit()` *(основной)*
#    - Обязательный метод для scikit-learn
#    - Возвращает self без изменений

# %%
# класс преобразования текста
class TextEmbedder(BaseEstimator, TransformerMixin):
    def __init__(self, model_name='all-MiniLM-L6-v2', lang='english', 
                 batch_size=32):
        self.model_name = model_name
        self.lang = lang
        self.batch_size = batch_size

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        model = SentenceTransformer(self.model_name)
        embeddings = model.encode(
            X,
            batch_size=self.batch_size,
            show_progress_bar=False,
            convert_to_numpy=True,
            normalize_embeddings=True
        )        
        return embeddings

# %%
# создаем экземпляр эмбеддера
model_te = TextEmbedder()

# %%
# векторизируем текст
#text_vectorize = model_te.transform(df_train['query_text_prep'])
df_train = df_train.reset_index(drop=True)
text_vectorize = model_te.transform(df_train['query_text'])

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Насколько я вижу для векторизации ты используешь лемматизированный текст. И это проблема. Т.к. исходный BERT, все остальные энкодеры, а также все современные GPT-подобные модели обучаются на "обычных", живых текстах. Для этих архитектур не нужно удалять стоп-слова, знаки препинания либо делать лемматизацию. Они способны работать с обычными "живыми" текстами.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Теперь для векторизации использую исходный текст.
# </div>

# %%
# проверка размерности полученного массива
text_vectorize.shape
# Out:
# (4080, 384)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Тут все ОК. Вектора описаний получены, да и моделька для семантического сходства использована очень неплохая</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Но есть нюансы, связанные с использованием DL фреймворков. В основном в проекте ты используешь Keras с бэкендом TensorFlow.  А вот sentence-transformers использует Pytorch.
#
# Поддержка двух DL фреймворков в одном проекте может вызывать сложности. Поэтому хорошей практикой является использование одного фреймворка в одном проекте.
#
# Но для тебя исправление этого замечания может потребовать переписывания большой части проекта, поэтому на стадии исследования я бы ничего менять уже не стал, просто имей в виду такой нюанс.
# </div>

# %% [markdown]
# ### Выводы по разделу:
# * Успешно использована предобученная модель: `all-MiniLM-L6-v2`
# * Для преобразования были использованы ~~подготовленные и очищенные~~ описания (`df_train['query_text']`).
# * Данные преобразованы в numpy-массив размером `(4252,384)`.

# %% [markdown]
# ## 5. Объединение векторов
#
# Подготовьте данные для обучения: объедините векторы изображений и векторы текстов с целевой переменной.

# %%
# объединение двух массивов "слева"
X = np.concatenate([image_vectorize, text_vectorize], axis=1)

# %%
# проверка размерности полученного массива
X.shape
# Out:
# (4080, 2432)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Вектора, полученные из текста и изображения объеденены👍 </div>

# %%
# конверитируем целевой признак в numpy-массив
y = np.array(df_train['final_score'])

# %%
# проверка размерности полученного массива
y.shape
# Out:
# (4080,)

# %% [markdown]
# ### Выводы по разделу:
# * Объеденены массивы эмбеддингов изображений и текстов в один.
# * Целевой признак выделил в отдельный массив, т.к. планирую при обучении использовать numpy-массивы, а не DataFrame.

# %% [markdown]
# ## 6. Обучение модели предсказания соответствия
#
# Для обучения разделите датасет на тренировочную и тестовую выборки. Простое случайное разбиение не подходит: нужно исключить попадание изображения и в обучающую, и в тестовую выборки.
# Для того чтобы учесть изображения при разбиении, можно воспользоваться классом [GroupShuffleSplit](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GroupShuffleSplit.html) из библиотеки sklearn.model_selection.
#
# Код ниже разбивает датасет на тренировочную и тестовую выборки в пропорции 7:3 так, что строки с одинаковым значением 'group_column' будут содержаться либо в тестовом, либо в тренировочном датасете.
#
# ```
# from sklearn.model_selection import GroupShuffleSplit
# gss = GroupShuffleSplit(n_splits=1, train_size=.7, random_state=42)
# train_indices, test_indices = next(gss.split(X=df.drop(columns=['target']), y=df['target'], groups=df['group_column']))
# train_df, test_df = df.loc[train_indices], df.loc[test_indices]
#
# ```
#
# Какую модель использовать — выберите самостоятельно. Также вам предстоит выбрать метрику качества либо реализовать свою.

# %% [markdown]
# ### 6.1. Обучение на классических моделях `LinearRegression` и `RandomForesRegressor`.

# %%
# Разделение данных с сохранением всех изображений группы в одном сете (train/test) при помощи GroupShuffleSplit
gss = GroupShuffleSplit(
    n_splits=1,
    train_size=TRAIN_SIZE,
    random_state=SEED
)

train_indices, valid_indices = next(
    gss.split(
        X=X,
        y=y,
        groups=df_train['image']
    )
)

# %%
# Разделение массива на тестовые и валидационные данные
X_train, y_train = X[train_indices], y[train_indices]
X_valid, y_valid = X[valid_indices], y[valid_indices]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, благодаря использованию GroupShuffleSplit ты исключаешь попадание одного изображения в обучающий и валидационный наборы.</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Только давай разберемся с выборками. Финальное тестирование (визуальное) мы делаем на отложенной выборке. Поэтому выборка,которую ты сейчас отделил играет роль валидационной. Есть смысл в её названии использовать слово valid а не test</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Переименова в valid.
# </div>

# %%
# подготовка пайплайна для обучения
pipe = Pipeline([
    ('model', RandomForestRegressor())
])

# %%
# гиперпараметры моделей
param_grid = [
    # Параметры для LR
    {
        'model': [LinearRegression(n_jobs=-1)],
        'model__fit_intercept': [True, False]
    },
    # Параметры для RandomFR
    {
        'model': [RandomForestRegressor(random_state=SEED, n_jobs=-1)],
        'model__n_estimators': [10, 25]
    }
]

# %%
# подготовка к кросс-валидации с 5 фолдами, сохраняя все изображения группы в одном фолде
# cv = GroupShuffleSplit(
#     n_splits=5,
#     train_size=TRAIN_SIZE,
#     random_state=SEED
# )

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Использовать кросс-валидацию имеет смысл если все модели мы будем оценивать с помощью кросс-валидации. Но это упирается в невозможность (точнее высокую сложность) применения кросс-валидации к нейронной сети.
#
# И честно  говоря не советую использовать кросс-валидацию в случае с нейронками. Причины тут самые разные - начиная с того, что нейронки могут очень долго обучаться и заканчивая тем, что при обучении нейронок часто очень сложно обеспечить воспроизводимость (повторяемость) результата.
#
# Ты конечно можешь в финале сравнить модели на валидационной выборке (сейчас она у тебя назыается X_test, y_test), но это лишнее усложнение. Я бы просто отказался от кросс-валидации и все модели оценивал на валидационной выборке.
#    </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Убрал кросс валидацию.
# </div>

# %% [markdown]
# В качестве метрики выберем `RMSE`, т.к. позволяет оценивать ошибку в исходных единицах измерения (у нас это процент соответсвия).

# %%
# инициализируем GredSearch
grid_search = GridSearchCV(
    pipe,
    param_grid,
    # cv=cv,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=1
)

# %%
# запускаем обучение моделей
model_grid = grid_search.fit(
    X=X_train,
    y=y_train
)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
print(f'Лучшая модель: {grid_search.best_estimator_}')
print(f'Лучшие параметры: {grid_search.best_params_}')
print(f'Лучший RMSE: {abs(grid_search.best_score_):.4f}')
# Out:
# Лучшая модель: Pipeline(steps=[('model',
#                  RandomForestRegressor(n_estimators=25, n_jobs=-1,
#                                        random_state=125))])
# Лучшие параметры: {'model': RandomForestRegressor(n_jobs=-1, random_state=125), 'model__n_estimators': 25}
# Лучший RMSE: 0.2391

# %%
valid_pred = model_grid.predict(X_valid)
valid_rmse = np.sqrt(mean_squared_error(y_valid, valid_pred))
print(f'Метрика RMSE на валидационной выборке: {valid_rmse:.4f}')
# Out:
# Test RMSE: 0.2292

# %% [markdown]
# * Лучшей моделью оказалась `RandomForestRegressor` с метрикой на `RMSE` ~~кросс-валидации~~ `0.1995`.
# * Попробуем создать нейросеть и проверить не получится ли метрика лучше.

# %% [markdown]
# ### 6.2. Обучение нейросети.

# %% [markdown]
# #### Класс `NNReg`
#
# Нейросетевая модель для задач регрессии.
#
# #### Основные методы:
#
# `__init__(input_shape, hidden_dim=256, drop_rate=[.5,.5], learning_rate=.002)`
#    - Инициализация с параметрами:
#      - `input_shape` - размерность входных данных
#      - `hidden_dim` - количество нейронов в скрытом слое
#      - `drop_rate` - уровни регуляризации Dropout
#      - `learning_rate` - скорость обучения оптимизатора Adam
#    - Автоматически строит модель через `_build()`
#
# `_build()` *(внутренний)*
#    - Конструирует архитектуру сети:
#      1. Входной Dense+ReLU слой → BatchNorm → Dropout
#      2. Скрытый Dense+ReLU слой → BatchNorm → Dropout
#      3. Выходной слой (1 нейрон с ReLU)
#    - Компилирует модель с MSE loss и RMSE метрикой
#
# `fit(X_train, y_train, validation_data=None, epochs=10, batch_size=32)` *(основной)*
#    - Процесс обучения:
#      - Поддержка валидационных данных
#      - Контроль через метрику RMSE
#      - Настройка количества эпох и размера батча
#
# `predict(X_test, y_test)` *(основной)*
#    - Выполняет предсказания:
#      1. Возвращает массив предсказанных значений
#      2. Автоматически вычисляет и выводит RMSE
#
# `summary()`
#    - Выводит информацию:
#      - Архитектуру модели
#      - Количество обучаемых параметров
#      - Структуру слоев

# %%
# класс нейросети
class NNReg:
    def __init__(self, input_shape=None, hidden_dim=256,
                 drop_rate=[.5,.5], learning_rate=.002):
        self.input_shape = input_shape
        self.drop_rate = drop_rate
        self.hidden_dim = hidden_dim
        self.learning_rate = learning_rate
        self.model = None
        self._build()
        
    def _build(self):
        inputs = Input(shape=(self.input_shape,))
        x = Dense(self.input_shape, activation='relu')(inputs)
        x = BatchNormalization()(x)
        x = Dropout(self.drop_rate[0])(x)
        x = Dense(self.hidden_dim, activation='relu')(x)
        x = BatchNormalization()(x)
        x = Dropout(self.drop_rate[1])(x)
        outputs = Dense(1, activation='relu')(x)
        self.model = Model(inputs=inputs, outputs=outputs)
        optimizer = Adam(learning_rate=self.learning_rate)
        self.model.compile(
            optimizer=optimizer,
            loss='mean_squared_error',
            metrics=[tf.keras.metrics.RootMeanSquaredError()]
        )
        return self.model
    
    def fit(self, X_train, y_train,
            epochs=10, batch_size=32, validation_data=None):
        return self.model.fit(
            X_train,
            y_train,           
            epochs=epochs,
            validation_data=validation_data,
            batch_size=batch_size
        )

    def summary(self):
        return self.model.summary()
        
    def predict(self, X_test, y_test=None):
        predictions = self.model.predict(X_test, verbose=0)
        if y_test is not None:
            rmse = np.sqrt(mean_squared_error(y_test, predictions))
            print(f'Test RMSE: {rmse:.4f}')
        return  np.squeeze(predictions)

# %%
# инициализация нейросети
model_nn = NNReg(
    input_shape=X_train.shape[1],
    hidden_dim=64,
    drop_rate=[.3, .4],
    learning_rate=.00002#.004
)

# %%
# вывод информации об архитектуре нейросети
model_nn.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 2432)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 2432)           │     5,917,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 2432)           │         9,728 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 2432)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# запускаем обучение на 20 эпохах
model_nn.fit(
    X_train,
    y_train,
    validation_data=[X_valid, y_valid],
    epochs=1000,
    batch_size=64
)
# Out:
# Epoch 1/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.1771 - root_mean_squared_error: 1.0837 - val_loss: 0.1217 - val_root_mean_squared_error: 0.3489
# Epoch 2/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8372 - root_mean_squared_error: 0.9146 - val_loss: 0.1157 - val_root_mean_squared_error: 0.3402
# Epoch 3/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7869 - root_mean_squared_error: 0.8870 - val_loss: 0.1374 - val_root_mean_squared_error: 0.3707
# Epoch 4/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7744 - root_mean_squared_error: 0.8796 - val_loss: 0.1443 - val_root_mean_squared_error: 0.3799
# Epoch 5/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6989 - root_mean_squared_error: 0.8357 - val_loss: 0.1739 - val_root_mean_squared_error: 0.4170
# Epoch 6/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6594 - root_mean_squared_error: 0.8119 - val_loss: 0.2005 - val_root_mean_squared_error: 0.4477
# Epoch 7/1000
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Что бы я доработал в логике построения / обучения модели.
#
#  - стоит уменьшить шаг обучения (скажем до 1е-5), но увеличить количество эпох. Стараться учить пока метрики на валидационной выборке улучшаются
#  - соответственно в процессе обучения делать оценку модели на валидационной выборке (добавляем параметр validation_data)
#
# Что касается использования dropout для регуляризации - то тут я тебя двумя руками поддерживаю. Без него хорошие результаты получить достаточно сложно
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Возможно ты воспринимаешь "количество эпох" как гиперпараметр "спущеный с верху". Т.е. устанавливаем параметры сети, запускаем обучение и смотрим на результат.
#
# В случае с нейронками логика ипользования немного отличается от того, к чему мы привыкли в классических моделях. Здесь лучше работать по другой логике:
#
#  - оределилили архитектуру, создали модель
#  - начинаем её учить. и учим пока метрика на валидационной выборке улучшается.  Наблюдая в динамике метрики на обучающей и валидационной выборках.
#  - если вдруг метрика на обучающей выборке перестала снижаться, можно попробовать уменьшить шаг обучения (например в 10 раз) и продолжить обучение модели.
#
# В любом случае полезно обучать модель пока метрика на валидации улучшается. Наша цель - оптимальное состояние модели, при котором модель хорошо находит законмоерности в данных, но еще не переобучилась.
#
# После того, как закончили обучение смотрим на логи, анализируем, чего модели не хватило, меняем архитектуру и запускаем обучение по новой.
#
#
#
#
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
#
# Для осознанной настройки нейронки важно понимать, как менять её архитектуру (усложнять и уменьшать регуляризацию? уменьшать шаг обучения? усиливать регуляризацию?). Для того чтобы принять эти  решения мало видеть только конечную цифру, важно понимать, чего модели не хватает чтобы метрика стала лучше.
#
#
# Вот типичные  проблемы, которые можно выявить  анализируя графики и пути их решения:
#
# <b>Недообучение (Underfitting)</b>
#   Признаки: Высокие значения потерь и низкая точность как на обучающей, так и на валидационной выборке. Графики потерь не снижаются (или снижаются  недостаточно).
#
#   Решения:
#
#  - Увеличение сложности модели (добавление слоев, увеличение числа нейронов).
#  - Использование более сложных моделей, таких как более глубокие нейронные сети.
#  - Увеличение количества эпох обучения.
#
# <b>Переобучение (Overfitting)</b>
#   Признаки: Значительное снижение потерь и увеличение точности на обучающей выборке, но высокие потери и низкая точность на валидационной выборке. Графики начинают расходиться после некоторого количества эпох.
#
#  Решения:
#   - Регуляризация (L1, L2 регуляризация).
#   - Dropout (добавление Dropout слоев).
#   - Уменьшение сложности модели (уменьшение числа слоев или нейронов).
#   - Использование аугментации данных для увеличения разнообразия данных.
#   - Раннее завершение обучения (Early Stopping) на основе валидационной ошибки.
#
# <b>Плохой выбор гиперпараметров</b>
#  Признаки: Нестабильные графики потерь и точности (большие колебания).
#
#  Решения:
#   - Настройка скорости обучения (learning rate).
#   - Оптимизация размера батча (batch size).
#   - Попробовать другие оптимизаторы (например, Adam, SGD с различными параметрами).
#
# </div>

# %% [markdown]
# * Тут небольшая проблема, не смог победить отсутсвие воиспроизводимости результата, метрика скачет то больше, то менньше чем на GredSearch. Видимо где то пропустил инициализацию генератора.
# * Лучшая метрика на тренировочных данных RMSE - `0.1937`
# * Т.к. не понял как реализовать механизм кросс-валидации, то проведем предсказание и оценку метрики на валидационных данных отдельно

# %%
# предсказание 
pred = model_nn.predict(X_valid, y_valid)
# Out:
# Test RMSE: 0.3313

# %% [markdown]
# Получена метрика `RMSE - 0.2012`

# %% [markdown]
# В качестве лучшей модели выбираем `RandomForestRegressor`

# %%
# берем лучшую модель из GredSearch
best_model = grid_search.best_estimator_

# %%
s

# %% [markdown]
# ### Выводы по разделу:
# * Применили GroupShuffleSplit для корректного разделения по изображениям, исключив утечку данных.
# * В качестве метрики выбрана `RMSE`, т.к. позволяет оценивать ошибку в исходных единицах измерения.
# * Обучили `LinearRegression` и `RandomForestRegressor` через GridSearchCV. RandomForest показал лучшую метрику `RMSE-0.1995`.
# * Реализовал 3х слойную сеть с регуляризацией. Метрика `RMSE-0.1937` на трейне.
# * Нейросеть показала `RMSE-0.2012` на валидационных данных, что хуже RandomForest.
# * Обнаружена проблема воспроизводимости в нейросети, вероятно где то нет фиксации random seed
# * В качестве финальной выбрана `RandomForestRegressor` с лучшей метрикой

# %% [markdown]
# ## 7. Тестирование модели
#
# Настало время протестировать модель. Для этого получите эмбеддинги для всех тестовых изображений из папки `test_images`, выберите случайные 10 запросов из файла `test_queries.csv` и для каждого запроса выведите наиболее релевантное изображение. Сравните визуально качество поиска.

# %%
# инициализация модели векторизации изображений и получение эмбеддингов для тестовых изображений
model = ImageVectorized()
test_image_vectorize = model.vectorized(df_test_img, TEST_IMAGE_PATH)#, seed=SEED)

# %%
# проверяем размерность полученных эмбеддингов
test_image_vectorize.shape

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Да, тестовые изображения оптимально векторизовать заранее.</div>

# %%
# выбираем 10 случайных запросов для тестирования
df_query = df_test.sample(10)

# %%
# предварительная обработка текста запросов
# preprocessor = TextPreprocessor(block=block_words['blockwords'].values.flatten().tolist())
# df_query['query_text_prep'] = preprocessor.transform(df_query['query_text'])

# %% [markdown]
# Создадим класс для обработки запросов и визуализации результата

# %% [markdown]
# #### Класс `ImagePredictor`
#
# Класс для обработки запросов и визуализации результатов поиска изображений.
#
# #### Основные методы:
#
# `__init__(model, text_embedder, test_image_path)`
#    - Инициализация с параметрами:
#      - `model` - обученная модель для предсказаний
#      - `text_embedder` - модель векторизации текста
#      - `test_image_path` - путь к тестовым изображениям
#
# `_prepare_features(text_embedding, image_embeddings)` *(внутренний)*
#    - Подготавливает объединенные признаки:
#      1. Дублирует текстовый эмбеддинг
#      2. Конкатенирует с эмбеддингами изображений
#
# `_display_top_images(df_top)` *(внутренний)*
#    - Визуализирует топ-5 изображений:
#      - Загрузка и отображение картинок
#      - Добавление оценок в заголовки
#      - Автоматическая компоновка
#
# `process_query(df_query, test_image_vectorize, df_test_img)` *(основной)*
#    - Полный pipeline обработки запроса:
#      1. Векторизация текста запроса
#      2. Объединение с эмбеддингами изображений
#      3. Предсказание релевантности
#      4. Вывод топ-5 результатов
#    - Обработка блокированных запросов ("BLOCK")

# %%
# класс для обработки запросов и визуализации результатов
class ImagePredictor:
    def __init__(self, model, text_embedder, test_image_path):
        self.model = model
        self.text_embedder = text_embedder
        self.test_image_path = test_image_path

    def _prepare_features(self, text_embedding, image_embeddings):
        text_embeddings = np.tile(text_embedding, (image_embeddings.shape[0], 1))
        return np.concatenate([image_embeddings, text_embeddings], axis=1)

    def _display_top_images(self, df_top):
        plt.figure(figsize=(20, 4))      
        for i, (_, row) in enumerate(df_top.iterrows()):
            img_path = os.path.join(self.test_image_path, row['image'])
            img = Image.open(img_path)
            plt.subplot(1, 5, i+1)
            plt.imshow(img)
            plt.title(f"Score: {row['predict']:.3f}", fontsize=12)
            plt.axis('off')
        plt.tight_layout()
        plt.show()

    def process_query(self, df_query, test_image_vectorize, df_test_img):
        for _, row in df_query.iterrows():
            print(f'QUERY: {row["query_text"]}')
            if row['query_text_prep'] == "BLOCK":
                print("*"*50, 
                      "| This image is unavailable in your country in compliance with local laws", 
                      "*"*50, sep="\n")
                continue
            text_embedding = self.text_embedder.transform([row['query_text']])
            features = self._prepare_features(text_embedding, test_image_vectorize)
            y_pred = self.model.predict(features)
            df_predict = pd.concat((df_test_img, pd.Series(y_pred, name="predict")), axis=1)
            top_5 = df_predict.sort_values('predict', ascending=False).head(5).copy()
            self._display_top_images(top_5)

# %%
# создаем векторизатор текста
text_embedder = TextEmbedder()

# %%
# инициализация класса обработки запросов
predict = ImagePredictor(
    model=best_model,
    text_embedder=text_embedder,
    test_image_path=TEST_IMAGE_PATH
)

# %%
# запуск обработки запросов
predict.process_query(df_query, test_image_vectorize, df_test_img)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Функции написаны и со своей задачей справляются. Принимают на вход текст и находят изображение. Отрабатывают контроль "запрещенного контента".
#
# Да, ты прав, к сожалению работают они не очень. Причин несколько
#
#  - при подготовке признаков допущена ошибка - вектора изображений перепутаны и фактически модель училась на "мусоре"
#  - врядли простые (классические) ML модели могут показать хороший результат. Я бы попытался улучшить результат нейронной сети.
#
# ----------------
#
# Как правило хороший результат в этом проекте удается достичь при выполнении следующих условий
#
#  - использование экспертных оценок
#  - векторизация изображений через pytorch, как есть в теории к спринту  (но с отрезанием только одного слоя). По моим наблюдениям с Resnet18 проще получить хороший результ. Возможно это связано с меньшим размером вектора (512), как следствие первый полносвязный слой получается "легче", меньше рисков переобучения.
#  - эмбеддинги через bert (лучший результат дает модель  `all-MiniLM-L6-v2`) (это ты уже сделал)
#  - упорное обучение нейронки (иногда тысячи эпох, в любом случае пока лосс снижается) с тщательным подбором гиперпараметров.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Идеи и альтернативные подходы</b>
#   Если хочешь получить хорошо работающее решение без обучения, то можешь провести эксперимент с нейронной сетью CLIP от OPEN AI (это не обязательно, только если хочешь добиться хороших результатов в этом проекте).
#
#   Про эту нейронку много где написано, но можешь посмотреть например вот здесь  https://habr.com/ru/post/539312/.
#
#   А для написания  реализации наиболее удобной лично для меня оказалась библиотека sbert. https://www.sbert.net/examples/applications/image-search/README.html
#
#
# <hr>
#
# Также неплохо работает следующий подход без предобученных моделей (к тому же легко реализуемый).
#
#
# Вместо того, чтобы подавать на вход модели изображение + текст и получать меру соответствия, поступаем по другому.
#
# На вход модели подаем вектор описания, а на выходе учимся предсказывать вектор изображения.
#
# По поводу метрик тут ситуация следующая. Точно работает следующий подход
#
#   - берем метрику mse, но тогда нужно чтобы модель её уменьшала. А значит в обучении используем только пары заведомо сответствующие друг другу
#
# Можно попробовать использовать косинусное расстояние, она позволяет использовать все данные (если есть соответствие то выдает 1, если нет то 0).
#
# Также можно попробовать усложнить модель, например и изображения и тексты отправлять в пространство размерностью 256 и уже в этом пространстве учиться их "сближать".
#
# По поводу методов векторизации: я бы использовать resnet18 для изображений (размерность эмбеддинга избражения 512) и БЕРТ для текстов (768).
#
#
# </div>

# %% [markdown]
# * Блокировка вывода изображения по блок словам работает.
# * Визульным осмотром установлено, что изображения не соотвествуют поисковым запросам. Больше похоже на случайную генерацию. Качество очень низкое.
# * Так же проскакивают фото с детьми, нужно дополнительно проработать список блок-слов.

# %% [markdown]
# ## Финальный вывод:
# * Начальный анализ выявил дисбаланс в оценках - большинство описаний не соответствуют изображениям.
# * Реализована система фильтрации нежелательного контента через блокировку слов.
# * Выполнена векторизация изображений с использованием ResNet50.
# * Проведена векторизация текста с помощью SBERT.
# * Для обучения и предсказания были выбраны LinearRegression, RandomForestRegressor и кастомная нейросеть.
# * Случайный лес показал лучгую метрику и был в качестве финальной модели.
# * Финальная модель демонстрирует недостаточное качество для использования в prod.
# * Вероятно из-за дисбаланса оценок мы имеем недостаточное количество описаний соотвествующих изображению.

# %% [markdown]
# ## 8. Выводы
#
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Исследовательский анализ данных выполнен
# - [x]  Проверены экспертные оценки и краудсорсинговые оценки
# - [x]  Из датасета исключены те объекты, которые выходят за рамки юридических ограничений
# - [x]  Изображения векторизованы
# - [x]  Текстовые запросы векторизованы
# - [x]  Данные корректно разбиты на тренировочную и тестовую выборки
# - [x]  Предложена метрика качества работы модели
# - [x]  Предложена модель схожести изображений и текстового запроса
# - [x]  Модель обучена
# - [x]  По итогам обучения модели сделаны выводы
# - [x]  Проведено тестирование работы модели
# - [x]  По итогам тестирования визуально сравнили качество поиска

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# Подведем итоги. Я вижу, что в целом с проектом ты справляешься.
#
# Проведено исследование и предобработка данных. Выполнена векторизация изображений и текстовых описаний. Обучены модели для предсказания степени соответствия, а также написан класс для инференса и с его помощью проведено тестирование.
#
# Пожалуйста отработай красные комментарии. Их не очень много ))
#
# Желтые комментарии на твое усмотрение. Но учитывая что наш подход "не взлетел" и нужно хоть что-то показать заказчику, попробуй показать возможный инференс с помщью CLIP. С библиотекой sentence-transformers это делается буквально в 10 строк.
# Жду твою работу на повторное ревью.
# </div>
